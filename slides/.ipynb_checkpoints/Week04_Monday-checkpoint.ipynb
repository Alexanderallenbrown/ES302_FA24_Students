# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Week-04-Monday" data-toc-modified-id="Week-04-Monday-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Week 04 Monday</a></span></li><li><span><a href="#Announcements" data-toc-modified-id="Announcements-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Announcements</a></span></li><li><span><a href="#Goals" data-toc-modified-id="Goals-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Goals</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Model-Construction" data-toc-modified-id="Model-Construction-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Model Construction</a></span></li><li><span><a href="#Final-model-for-Romi-forward-motion" data-toc-modified-id="Final-model-for-Romi-forward-motion-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Final model for Romi forward motion</a></span></li><li><span><a href="#How-will-we-&quot;fit&quot;-unknown-parameters-in-this-model-so-we-can-use-it?" data-toc-modified-id="How-will-we-&quot;fit&quot;-unknown-parameters-in-this-model-so-we-can-use-it?-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>How will we "fit" unknown parameters in this model so we can use it?</a></span><ul class="toc-item"><li><span><a href="#We-will-use-the-data-you-collected!-We-can-infer-a-couple-of-key-things-from-the-data." data-toc-modified-id="We-will-use-the-data-you-collected!-We-can-infer-a-couple-of-key-things-from-the-data.-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>We will use the <em>data</em> you collected! We can infer a couple of key things from the data.</a></span></li></ul></li><li><span><a href="#What-did-your-Romi-data-look-like-for-forward-speed?" data-toc-modified-id="What-did-your-Romi-data-look-like-for-forward-speed?-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>What did your Romi data look like for forward speed?</a></span></li><li><span><a href="#How-can-we-characterize-a-first-order-response-numerically?" data-toc-modified-id="How-can-we-characterize-a-first-order-response-numerically?-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>How can we characterize a first-order response <em>numerically?</em></a></span></li><li><span><a href="#How-can-we-characterize-a-first-order-response's--transient-behavior?" data-toc-modified-id="How-can-we-characterize-a-first-order-response's--transient-behavior?-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>How can we characterize a first-order response's  <em>transient behavior?</em></a></span></li><li><span><a href="#How-can-we-characterize-a-first-order-response's--transient-behavior?" data-toc-modified-id="How-can-we-characterize-a-first-order-response's--transient-behavior?-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>How can we characterize a first-order response's  <em>transient behavior?</em></a></span><ul class="toc-item"><li><span><a href="#Time-Constant" data-toc-modified-id="Time-Constant-15.1"><span class="toc-item-num">15.1&nbsp;&nbsp;</span>Time Constant</a></span></li></ul></li><li><span><a href="#How-can-we-characterize-a-first-order-response's-steady-state-behavior?" data-toc-modified-id="How-can-we-characterize-a-first-order-response's-steady-state-behavior?-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>How can we characterize a first-order response's <em>steady state</em> behavior?</a></span></li><li><span><a href="#How-can-we-characterize-a-first-order-response's-steady-state-behavior?" data-toc-modified-id="How-can-we-characterize-a-first-order-response's-steady-state-behavior?-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>How can we characterize a first-order response's <em>steady state</em> behavior?</a></span><ul class="toc-item"><li><span><a href="#Steady-State-Gain-$\equiv-\frac{\Delta-y_{ss}}{\Delta-U_{ss}}$" data-toc-modified-id="Steady-State-Gain-$\equiv-\frac{\Delta-y_{ss}}{\Delta-U_{ss}}$-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>Steady State Gain $\equiv \frac{\Delta y_{ss}}{\Delta U_{ss}}$</a></span></li></ul></li><li><span><a href="#Solving-for-$\tau$-and-$K_{ss}$-for-your-Romi-data-will-allow-you-to-compare-these-numbers-with-your-model-to-solve-for-unknown-parameters!" data-toc-modified-id="Solving-for-$\tau$-and-$K_{ss}$-for-your-Romi-data-will-allow-you-to-compare-these-numbers-with-your-model-to-solve-for-unknown-parameters!-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Solving for $\tau$ and $K_{ss}$ for your Romi data will allow you to compare these numbers with your model to solve for unknown parameters!</a></span></li><li><span><a href="#Calibrating-and-characterizing-sensors" data-toc-modified-id="Calibrating-and-characterizing-sensors-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Calibrating and characterizing sensors</a></span></li><li><span><a href="#Rotary-encoders-provide-angular-position-measurements-in-&quot;counts&quot;" data-toc-modified-id="Rotary-encoders-provide-angular-position-measurements-in-&quot;counts&quot;-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Rotary encoders provide angular position measurements in "counts"</a></span></li><li><span><a href="#How-do-wheel-radians-relate-to-Romi-forward-motion?" data-toc-modified-id="How-do-wheel-radians-relate-to-Romi-forward-motion?-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>How do wheel radians relate to Romi forward motion?</a></span></li><li><span><a href="#Rotary-potentiometers-measure-the-position-of-each-of-Romi's-servos." data-toc-modified-id="Rotary-potentiometers-measure-the-position-of-each-of-Romi's-servos.-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Rotary potentiometers measure the position of each of Romi's servos.</a></span></li><li><span><a href="#Rotary-potentiometers-measure-the-position-of-each-of-Romi's-servos." data-toc-modified-id="Rotary-potentiometers-measure-the-position-of-each-of-Romi's-servos.-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>Rotary potentiometers measure the position of each of Romi's servos.</a></span></li><li><span><a href="#Sometimes-conversions-are-easier-with-experimental-data" data-toc-modified-id="Sometimes-conversions-are-easier-with-experimental-data-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Sometimes conversions are easier with experimental data</a></span></li><li><span><a href="#IR-distance-sensors-are-highly-nonlinear!" data-toc-modified-id="IR-distance-sensors-are-highly-nonlinear!-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>IR distance sensors are highly nonlinear!</a></span></li><li><span><a href="#IR-distance-sensors-are-highly-nonlinear!" data-toc-modified-id="IR-distance-sensors-are-highly-nonlinear!-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>IR distance sensors are highly nonlinear!</a></span></li></ul></div>

# %% [markdown]
# ## Week 04 Monday
# Sept 16, 2024
#
# ## Announcements
# 2. A05 Lit review is released; due Oct 11. First **intermediate** deadline is **Wednesday 9/18/2024**
# 3. A04 has been released, due **Wednesday, 9/25/2024**
#
# ## Goals
#
# 1. Romi forward motion model construction (45 minutes)
# 2. Sensor calibration discussion (if time)
# 3. Work time for A04 (30 minutes)

# %% [markdown]
# Our model will be a first-order differential equation, and will have the form:
#
# $$\dot{v} = \square v + \star V_{in}$$

# %% [markdown]
# ## Model Construction
#
# What elements would go in our model?

# %% [markdown]
# ## Model Construction
#
# What elements would go in our model?

# %% [markdown]
# ## Model Construction
#
# How are our elements arranged in an equivalent circuit?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Model Construction
#
# What are the elemental, loop and node equations for this circuit?

# %% [markdown]
# ## Model Construction
#
# What are the elemental, loop and node equations for this circuit?

# %% [markdown]
# **Nodes**
# \begin{equation}
# i = i
# \end{equation}
# \begin{equation}
# T_m = T_b+T_J+T_r
# \end{equation}
# \begin{equation}
# F_r=F_m
# \end{equation}

# %% [markdown]
# **Loops**
# \begin{equation}
# V_{1g} = V_{12}+V_{2g}
# \end{equation}

# %% [markdown]
# **Elements**
# \begin{equation}
# V_{12}=iR
# \end{equation}
# \begin{equation}
# k_t i = T_m
# \end{equation}
# \begin{equation}
# k_t \Omega_{1g} = V_{2g}
# \end{equation}
# \begin{equation}
# T_b = b\Omega_{1g}
# \end{equation}
# \begin{equation}
# T_J = J\dot{\Omega}_{1g}
# \end{equation}
# \begin{equation}
# T_r = rF_r
# \end{equation}
# \begin{equation}
# v_{1g} = r\Omega_{1g}
# \end{equation}
# \begin{equation}
# F_m = m\dot{v}_{1g}
# \end{equation}

# %% [markdown]
# ## Model Construction
#
# Let's work through the algebra!

# %% [markdown]
# ## Final model for Romi forward motion

# %% [markdown]
# \begin{equation}
#  \dot{v} = \frac{1}{\frac{J}{r} + mr}\left( \frac{k_t}{R} V_{in} - \left(\frac{k_t^2}{R r} + \frac{b}{r} \right)v \right)
# \end{equation}

# %% [markdown]
# Don't forget to confirm units and signs (internal validity!!)

# %% [markdown]
# ## How will we "fit" unknown parameters in this model so we can use it?

# %% [markdown]
# ### We will use the *data* you collected! We can infer a couple of key things from the data.

# %% [markdown]
# * *Steady state behavior* (what happens once everything stops changing)
# * *Transient behavior* (how the system reaches steady state)

# %% [markdown]
# ## What did your Romi data look like for forward speed?
#
# This is fictitious data... yours may be different!!

# %%
from control.matlab import step,tf
from numpy import *
from matplotlib.pyplot import *

tau = 0.05
SS = 0.9
noise = 0.1

model = control.matlab.tf([SS],[tau, 1])
ymodel,t = control.matlab.step(model)
for k in range(0,len(ymodel)):
    ymodel[k]+=(random.randint(-2,2))*noise
    
figure()
plot(t,ymodel,'k')
xlabel('Time (s)')
ylabel('Romi Speed (m/s)')
# Out:
# Text(0, 0.5, 'Romi Speed (m/s)')

# %% [markdown]
# ## How can we characterize a first-order response *numerically?*

# %% [markdown]
# ## How can we characterize a first-order response's  *transient behavior?*

# %% [markdown]
# ## How can we characterize a first-order response's  *transient behavior?*

# %% [markdown]
# Given a linear differential equation of the form $a_1\dot{y} + a_0y = b_0U$, we can use the *time constant* to characterize its **transient behavior.**

# %% [markdown]
# ### Time Constant
# * For a first order system, the system's single eigenvalue is $p=-\frac{a_0}{a_1}$.
# * We define the time constant to be $\tau = \frac{a_1}{a_0} = -\frac{1}{p}$
# **WHY?**
# When $t = \tau$, then the differential equation's **homogeneous** solution is
# \begin{equation}
# y_h(t) = y_0e^{-\frac{t}{\tau}} = y_oe^{-1} = 0.367879y_0
# \end{equation}
#
# This means that if $y(\tau) = 0.368 y_0$, then approximately 63.2% of the **change** from $t_0$ to $t_{ss}$ has occurred when $t=\tau$. For step responses, this means that the time constant can be pulled off of a plot by finding the time $\tau$ at which $y(t) = 0.632(y_{ss}-y_0)$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How can we characterize a first-order response's *steady state* behavior?

# %% [markdown]
# ## How can we characterize a first-order response's *steady state* behavior?

# %% [markdown]
# ### Steady State Gain $\equiv \frac{\Delta y_{ss}}{\Delta U_{ss}}$

# %% [markdown]
# Given a first-order linear differential equation of the form $a_1\dot{y} + a_0y = b_0U$, setting $\dot{y}=0$ to indicate *steady state*, and solving for the change in our output at steady state yields
#
# $$\Delta y_{ss} = y_{ss}-y_0 = \left(U_{ss} - U_0\right)\frac{b_0}{a_0}$$
#
# This allows us to write an equation for "steady state gain" using the first-order differential equation's $a_0$ and $b_0$ terms.

# %% [markdown]
# $$K_{ss} = \frac{y_{ss}-y_0}{U-U_0} = \frac{\Delta y_{ss}}{\Delta u_{ss}} = \frac{b_0}{a_0} $$

# %% [markdown]
# ## Solving for $\tau$ and $K_{ss}$ for your Romi data will allow you to compare these numbers with your model to solve for unknown parameters!
#
# This will be your challenge for Assignment 6 (upcoming).

# %% [markdown]
# ## Calibrating and characterizing sensors
#
# so far in ES302, you've used three types of sensors to varying degrees
# * [Rotary Encoders](https://en.wikipedia.org/wiki/Rotary_encoder) that measure Romi's drive wheel motion
# * [infrared distance sensors](https://itp.nyu.edu/physcomp/distance-sensors-the-basics/) on the Romi's arm
# * [Rotary potentiometers](https://en.wikipedia.org/wiki/Potentiometer)

# %% [markdown]
# ## Rotary encoders provide angular position measurements in "counts"

# %% [markdown]
# ![encoder.gif](attachment:encoder.gif)

# %% [markdown]
# The Romi's wheel motors are each equipped with a rotary encoder. The conversion from counts to radians depends on the gear ratio, counts per revolution, etc. and can be computed using dimensional analysis. Assuming a 1:1 gear ratio, an example is provided below.
#
# \begin{equation}
# \require{cancel}
# rad = \frac{\cancel{rev}}{\cancel{count}}\times\frac{2\pi \:rad}{\cancel{rev}}
# \end{equation}

# %% [markdown]
# ## How do wheel radians relate to Romi forward motion?
# If we assume no-slip between the Romi tires and ground, we can model this relationship using the arc-length formula!
# ![image.png](attachment:image.png)
# \begin{equation}
# \frac{d}{dt}x = r \frac{d}{dt}\theta
# \end{equation}
# \begin{equation}
# v = r \omega
# \end{equation}

# %% [markdown]
# ## Rotary potentiometers measure the position of each of Romi's servos.

# %% [markdown]
# A rotary potentiometer is simply an adjustable voltage divider!
# ![DHuK7T.gif](attachment:DHuK7T.gif)

# %% [markdown]
# \begin{equation}V_{out} = V_{in}\frac{R_1}{R_1+R_2}\end{equation}

# %% [markdown]
# ## Rotary potentiometers measure the position of each of Romi's servos.

# %% [markdown]
# An [analog to digital converted](https://en.wikipedia.org/wiki/Analog-to-digital_converter) converts voltages between 0 and 5V on an Arduino "analog pin" to a 10-bit number, meaning that the relationship between ADC "counts" and "volts" can be derived analytically:

# %%
from numpy import *
from matplotlib.pyplot import *
volts = linspace(0,5,100)
counts = volts*1023.0/5.0
figure()
plot(counts,volts,'k')
grid('minor')
ylabel('Voltage')
xlabel('Counts')
# Out:
# Text(0.5, 0, 'Counts')

# %% [markdown]
# \begin{equation}
# \require{cancel}
# V = \cancel{counts} \times \frac{5.0V}{1023\cancel{counts}}
# \end{equation}
#
# However, this doesn't give the conversion between volts at the potentiometer wiper and servo arm degrees!

# %% [markdown]
# ## Sometimes conversions are easier with experimental data
# Converting counts to volts on the servos' rotary potentiometers doesn't help convert to position! If I move the servo (by hand, for example) to two known positions, I can produce a best-fit line using point-slope form. Let's say I let a servo achieve steady-state at 90 degrees, and 110 degrees, and then read the potentiometer value in counts.

# %%
counts_exp = [308,350]
deg_exp = [90,110]
m = (deg_exp[-1]-deg_exp[0])/(counts_exp[-1]-counts_exp[0])
counts_lin = linspace(0,1023,25)
deg_lin = m*(counts_lin-counts_exp[0])+deg_exp[0]
figure()
plot(counts_exp,deg_exp,'ko',markersize=10)
plot(counts_lin,deg_lin,'r')
legend(['measured','linear fit: m='+str(m)+' deg/count'])
xlabel('ADC counts')
ylabel('degrees')
grid('on')

# %% [markdown]
# After finding the slope between your two known points, can then find the degree value for any count value using that slope and one of your known combinations of degrees and counts:
# \begin{equation}
# deg = m(counts-counts_{known})+deg_{known}
# \end{equation}
#
# This is *not as accurate* as a true "linear fit" because it does not account for noise! If you wanted to use a true linear fit, you could consult [this section](https://alexanderallenbrown.github.io/ES103_SP23_Students/ES103_Summary_Resource/ES103_Summary_Resource.html#Empirical-Models:-fitting-polynomials-in-MATLAB/Octave) from ES103.

# %% [markdown]
# ## IR distance sensors are highly nonlinear!

# %% [markdown]
# the reading given by the sensor is often very sensitive to IR reflectivity of the environment.
# ![image-2.png](attachment:image-2.png)
#
# Sometimes, producing a [lookup table](https://alexanderallenbrown.github.io/ES103_SP23_Students/ES103_Summary_Resource/ES103_Summary_Resource.html#Linear-Interpolation) and using linear interpolation (either using numpy.interp or manually with point-slope form) is the best way to convert from IR "counts" to meters.

# %% [markdown]
# ## IR distance sensors are highly nonlinear!

# %%
ir_data=array([[0.0254,991,.005,],[0.0508,987,.005,],[0.0762,980,.005,],[0.1016,853,.005,],[0.127,712,.005,],[0.1524,585,.005,],[0.1778,502,.005,],[0.2032,435,.005,],[0.2286,383,.005,],[0.254,346,.005,],[0.2794,316,.005,],[0.3048,296,.005,],[0.3302,281,.005,],[0.3556,268,.005,],[0.381,255,.005,],[0.4064,248,.005,],[0.4318,239,.005,],[0.4572,233,.005,],[0.4826,229,.005,],[0.508,223,.005,],[0.5334,219,.005,],[0.5588,215,.005,],[0.5842,211,.005,],[0.6096,209,.005,],[0.635,207,.005,],[0.6604,205,.005,],[0.6858,203,.005,],[0.7112,201,.005,],[0.7366,200,.005]])
ind = 5
m= (ir_data[ind,0]-ir_data[ind+1,0])/(ir_data[ind,1]-ir_data[ind+1,1])
query = int(mean([ir_data[ind,1],ir_data[ind+1,1]]))
interped = m*(query-ir_data[ind,1])+ir_data[ind,0]

xlin = ir_data[ind-5:ind+5,1]
lin = m*(xlin-ir_data[ind,1])+ir_data[ind,0]

figure()
plot(ir_data[:,1],ir_data[:,0],'k.')
plot(xlin,lin,'r')
plot(query,interped,'ro')

legend(['data','interpolated line','interpolated result'])
xlabel('ADC counts')
ylabel('Distance to white paper (m)')
# Out:
# Text(0, 0.5, 'Distance to white paper (m)')
